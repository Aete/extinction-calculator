# %%
import os

import numpy as np
import pandas as pd

# %%
raw_data_dir = './raw_data'
list_csv = os.listdir(raw_data_dir)
list_working_age = ['15 - 19세', '20-24세',
       '25-29세', '30-34세', '35-39세', '40-44세', '45-49세', '50-54세',
       '55-59세', '60-64세'  ]

dict_sido = {
    'seoul':'서울',
    'busan':'부산',
    'daegu':'대구'
}

# %%
def process_data(csv):
    df_sample = pd.read_csv(f'{raw_data_dir}/{csv}')
    df_sample['sido'] = dict_sido[csv.replace('_future_pop.csv','')]
    df_sample.drop('성별', axis=1, inplace=True)
    df_sample.rename(columns={'시군구별':'sigungu', '연령별':'age'}, inplace=True)

    df_total = df_sample.loc[df_sample['age']=='계'].drop('age', axis=1)

    df_working_age = df_sample.loc[df_sample['age'].isin(list_working_age)]
    df_working_age = df_working_age.groupby(['sido','sigungu'], as_index=False).sum()

    return df_total, df_working_age

list_df_total = []
list_df_working_age = []

for csv in list_csv:
    df_total, df_working_age = process_data(csv)
    list_df_total.append(df_total)
    list_df_working_age.append(df_working_age)

df_total = pd.concat(list_df_total, ignore_index=True)
df_working_age = pd.concat(list_df_working_age, ignore_index=True)
# Out:
# C:\Users\seung\AppData\Local\Temp\ipykernel_22332\3728636487.py:10: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_working_age = df_working_age.groupby(['sido','sigungu'], as_index=False).sum()
# C:\Users\seung\AppData\Local\Temp\ipykernel_22332\3728636487.py:10: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_working_age = df_working_age.groupby(['sido','sigungu'], as_index=False).sum()
# C:\Users\seung\AppData\Local\Temp\ipykernel_22332\3728636487.py:10: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_working_age = df_working_age.groupby(['sido','sigungu'], as_index=False).sum()

# %%
df_total
# Out:
#    sigungu     2022     2023     2024     2025     2026     2027     2028  \
# 0       부산  3303196  3284246  3264616  3238541  3212144  3186255  3160958
# 1       중구    41340    40705    39570    38554    37763    37152    36679
# 2       서구   103385   104083   102948   101482   100173    99023    98034
# 3       동구    86511    85907    86246    86759    86995    87014    86866
# 4      영도구   110401   108668   106999   105271   103525   101807   100129
# 5     부산진구   347476   354611   359629   361822   362352   361630   359870
# 6      동래구   267611   266303   263732   262503   261615   261031   260683
# 7       남구   259788   257378   257801   255795   253115   249963   246430
# 8       북구   276072   272619   267464   263356   259863   256904   254397
# 9     해운대구   379819   372340   366898   360611   355225   350686   346823
# 10     사하구   304692   301369   295020   288977   283788   279351   275582
# 11     금정구   228756   224273   218113   212219   207092   202737   199088
# 12     강서구   143789   143633   143137   142981   143190   143689   144419
# 13     연제구   201394   198485   208558   214602   218055   219407   219014
# 14     수영구   169820   170868   169150   167852   166765   165878   165133
# 15     사상구   208666   207147   205288   202585   199783   196960   194157
# 16     기장군   173676   175857   174063   173172   172845   173023   173654
# 17      대구  2371593  2359734  2353742  2334535  2315299  2296541  2278256
# 18      중구    76853    82312    91499    95859    98169    98908    98413
# 19      동구   333566   332988   337666   338365   338357   337814   336795
# 20      서구   161124   159926   164015   164440   163857   162459   160373
# 21      남구   141660   142242   138021   134189   131377   129441   128230
# 22      북구   441962   434313   424282   418316   413070   408540   404715
# 23     수성구   404802   398893   401209   399278   397080   394629   391944
# 24     달서구   545773   542805   534049   523927   515032   507321   500570
# 25     달성군   265853   266255   263001   260161   258357   257429   257216
# 26      서울  9421415  9400365  9393699  9339904  9286528  9235940  9187423
# 31   329437   326650  ...   317393   315496   313719   312007   310260
# 32   350366   347950  ...   341138   339817   338498   337100   335579
# 33   365786   364277  ...   358652   357302   355965   354608   353195
# 34   412752   410402  ...   402984   401390   399765   398067   396209
# 35   262466   260183  ...   252331   250625   248992   247402   245823
# 36   283138   280552  ...   271959   270128   268390   266710   265045
# 37   464689   460504  ...   446708   443768   440900   438093   435304
# 38   450268   448531  ...   442271   440830   439416   438012   436547
# 39   304020   302780  ...   299407   298755   298082   297325   296440
# 40   352084   350613  ...   345220   343981   342736   341460   340055
# 41   407125   405098  ...   397313   395531   393832   392192   390572
# 42   529385   526655  ...   516070   513567   511102   508704   506269
# 43   402452   401025  ...   395784   394490   393169   391820   390361
# 44   235058   233570  ...   228361   227222   226149   225106   224067
# 45   394477   393312  ...   388305   387002   385689   384332   382877
# 46   367219   364511  ...   356132   354422   352751   351071   349278
# 47   464621   460462  ...   446778   444130   441676   439295   436857
# 48   387874   385531  ...   376630   374573   372575   370623   368672
# 49   560586   558461  ...   548159   545428   542721   540115   537565
# 50   615988   614477  ...   608241   606586   604865   603065   601112
# 51   478435   482844  ...   496115   498480   500508   502202   503504
#
#        2039     2040     2041     2042  sido
# 0   2883319  2853768  2823197  2791801    부산
# 1     33237    32895    32524    32140    부산
# 2     89262    88343    87374    86379    부산
# 3     81964    81317    80646    79923    부산
# 4     86048    84904    83744    82583    부산
# 5    331972   328770   325377   321814    부산
# 6    247725   245629   243430   241138    부산
# 7    213046   210142   207213   204282    부산
# 8    231822   229519   227144   224693    부산
# 9    311565   308209   304802   301375    부산
# 10   244515   241597   238623   235582    부산
# 11   174447   172298   170087   167832    부산
# 12   140518   139335   138104   136839    부산
# 13   199708   197678   195604   193480    부산
# 14   154326   152965   151523   150003    부산
# 15   169449   167281   165043   162769    부산
# 16   173715   172886   171959   170969    부산
# 17  2084333  2064892  2044944  2024535    대구
# 18    86198    85165    84113    83046    대구
# 19   317542   315199   312726   310155    대구
# 20   138744   137098   135445   133780    대구
# 21   119619   118610   117538   116409    대구
# 22   370851   367355   363736   360043    대구
# 23   358543   355376   352154   348882    대구
# 24   444288   439330   434339   429274    대구
# 25   248548   246759   244893   242946    대구
# 26  8753578  8709899  8662766  8612169    서울
# 27   130320   129636   128900   128099    서울
# 28   119278   118702   118067   117367    서울
# 29   188920   187845   186705   185509    서울
# 30   245992   244140   242212   240204    서울
# 31   308429   306484   304393   302152    서울
# 32   333849   331885   329711   327356    서울
# 33   351651   349986   348181   346233    서울
# 34   394137   391877   389418   386811    서울
# 35   244209   242556   240829   239033    서울
# 36   263337   261597   259807   257978    서울
# 37   432446   429530   426558   423543    서울
# 38   434979   433290   431464   429493    서울
# 39   295376   294134   292705   291128    서울
# 40   338487   336732   334809   332698    서울
# 41   388923   387214   385440   383585    서울
# 42   503708   501002   498136   495105    서울
# 43   388772   387062   385205   383195    서울
# 44   222968   221814   220585   219241    서울
# 45   381252   379468   377504   375366    서울
# 46   347341   345195   342867   340368    서울
# 47   434208   431276   427989   424299    서울
# 48   366668   364641   362566   360439    서울
# 49   535020   532476   529917   527320    서울
# 50   598914   596470   593797   590912    서울
# 51   504394   504887   505001   504735    서울
#
# [52 rows x 23 columns]
